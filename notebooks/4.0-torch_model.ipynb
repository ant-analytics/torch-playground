# %% [markdown]
# # 1. Introduction

# %%
import os
import time
from datetime import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# pytorch related
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import Dataset, DataLoader

# utils libraries
from tqdm import tqdm
import yaml # for config file

# scikir-learn
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
# set global state
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_cpu = os.cpu_count()
print(f'This machine run on {device} with {num_cpu} cpus')

# fundtion load config
def load_config(config_path):
    with open(config_path, 'r') as file:
        config = yaml.safe_load(file)
    return config

# load config
config = load_config('/mnt/d/torch-playground/scripts/config.yaml')
# Out:
# This machine run on cuda with 8 cpus

# %% [markdown]
# # 2. Dataset and Dataloader

# %%
# create custom dataset class
class CustomDataset(Dataset):
    '''
    Custom dataset class for loading
    input: file path
    output: tensor
    '''
    def __init__(self, file_path, target_status, target_score):
        self.file_path = file_path
        self.target_status = target_status
        self.target_score = target_score
        self.data = pd.read_csv(file_path)

        self.X = self.data.drop([target_status, target_score], axis=1)
        self.y_status = self.data[target_status]
        self.y_score = self.data[target_score]

    def __len__(self):
        '''
        return the number of samples
        '''
        return len(self.data)
    
    def __getitem__(self, idx):
        '''
        return the sample at index idx
        if use .reshape(-1, 1) to add dimension --> every sample will be shape (1,1)
        when batched, it will be shape (batch_size, 1, 1)
        if use .unsqueeze(-1) to add dimension --> every sample will be shape (1,)
        when batched, it will be shape (batch_size, 1); use .unsqueeze(-1) recommended
        '''
        
        X = torch.tensor(self.X.iloc[idx].values, dtype=torch.float32)
        target_status = torch.tensor(self.y_status.iloc[idx], dtype=torch.float32).unsqueeze(-1) # add dimension
        target_score = torch.tensor(self.y_score.iloc[idx], dtype=torch.float32).unsqueeze(-1) # add dimension
        return X, target_score, target_status

# %% [markdown]
# # 3. Project Hyperparameters

# %%
# set hyperparameters
# data 
train_path = config['data']['train_path']
val_path = config['data']['val_path']
test_path = config['data']['test_path']
target_status = config['data']['target_status']
target_score = config['data']['target_score']
batch_size = config['training']['batch_size']

# model
input_size = config['model']['input_size']
hidden_size_1 = config['model']['hidden_size_1']
hidden_size_2 = config['model']['hidden_size_2']
hidden_size_3 = config['model']['hidden_size_3']
output_size_status = config['model']['output_size_status']
output_size_score = config['model']['output_size_score']

# training
learning_rate = config['training']['learning_rate']
epochs = config['training']['epochs']
patience = config['training']['patience']
min_delta = config['training']['min_delta']

# logging
timestamp = datetime.now().strftime('%Y_%m_%d_%H_%M_%S')

# checkpoint directory
checkpoint_dir = f"{config['logging']['checkpoint_dir']}/{timestamp}"

# tensorboard log directory
tensorboard_log_dir = f'{config['logging']['tensorboard_log_dir']}/{timestamp}'
writer = SummaryWriter(log_dir=tensorboard_log_dir) # initialise tensorboard writer

# %%
# train dataset and train loader
train_dataset = CustomDataset(file_path=train_path, target_status=target_status, target_score=target_score)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_cpu)

# validation dataset and validation loader
val_dataset = CustomDataset(file_path=val_path, target_status=target_status, target_score=target_score)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_cpu)

# test dataset and test loader
test_dataset = CustomDataset(test_path, target_status=target_status, target_score=target_score)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_cpu)

# %%
for i, (X, y_status, y_score) in enumerate(train_loader):
    print(f'this is shape of X: {X.shape}')
    print(f'this is shape of y_status: {y_status.shape}')
    print(f'this is shape of y_score: {y_score.shape}')
    break
# Out:
# this is shape of X: torch.Size([64, 18])
# this is shape of y_status: torch.Size([64, 1])
# this is shape of y_score: torch.Size([64, 1])

# %% [markdown]
# # 4. Model Architecture

# %%
# model architecture
class LoanModel(nn.Module):
    '''
    Docstring for LoanModel
    '''
    def __init__(self, input_size, hidden_size_1, hidden_size_2, hidden_size_3, output_size_score, output_size_status):
        '''
        Docstring for __init__
        '''
        super().__init__() # no need to pass class and self

        # shared layers
        self.fc1 = nn.Linear(input_size, hidden_size_1)
        self.fc2 = nn.Linear(hidden_size_1, hidden_size_2)
        self.fc3 = nn.Linear(hidden_size_2, hidden_size_3)
        
        # output layer for regression
        self.regression_head = nn.Linear(hidden_size_3, output_size_score) # output size for regression

        # output layer for binary classification
        self.classification_head = nn.Linear(hidden_size_3, output_size_status) # output size for classification

    def forward(self, x):
        '''
        Docstring for forward
        '''
        # shared layers
        # relu activation function for hidden layers
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))

        # regression head
        score_output = self.regression_head(x) # no activation function for regression

        # classification head
        # sigmoid for binary classification
        status_output = torch.sigmoid(self.classification_head(x))

        return score_output, status_output

# %% [markdown]
# # 5. Loss Function

# %%
# loss for credit score
score_loss_fn = nn.MSELoss(reduction='mean')
status_loss_fn = nn.BCELoss(reduction='mean')

# %% [markdown]
# # 6. Optimiser

# %%
#  instantiate model
model = LoanModel(input_size, hidden_size_1, hidden_size_2, hidden_size_3, output_size_score, output_size_status).to(device)

# score optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # 7. Train and Evaluate Functions

# %% [markdown]
# ## 7.1. Model Metric Functions

# %%
def compute_classification_metrics(status_output, target_status, threshold=0.5):
    '''
    Docstring for compute_classification_metrics

    Args:
        status_output: (torch.tensor) model output for status
        status_target: (torch.tensor) target from dataset for status
        threshold: (float) threshold for classification to convert probability to binary, default 0.5

    Retunrs: Dict of accuracy, precision, recall, f1
    '''

    # convert probability to binary
    status_output = (status_output > threshold).float() # convert to float

    # move to cpu and convert to numpy
    status_output = status_output.cpu().detach().numpy()
    target_status = target_status.cpu().detach().numpy()

    # compute metrics
    accuracy = accuracy_score(target_status, status_output)
    precision = precision_score(target_status, status_output)
    recall = recall_score(target_status, status_output)
    f1 = f1_score(target_status, status_output)

    return {'accuracy': accuracy, 'precision': precision, 'recall': recall, 'f1': f1}

# %% [markdown]
# ## 7.2. Plot Confusion Matrix

# %%
def plot_confusion_matrix(target_status, status_output, class_names, threshold=0.5):
    '''
    
    '''
    # convert probability to binary
    status_output = (status_output > threshold).float() # convert to float

    # move to cpu and convert to numpy
    status_output = status_output.cpu().detach().numpy()
    target_status = target_status.cpu().detach().numpy()

    cm = confusion_matrix(target_status, status_output)
    fig, ax = plt.subplots(figsize=(5, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    ax.set_xlabel("Predicted Label")
    ax.set_ylabel("True Label")
    ax.set_title("Confusion Matrix")
    
    return fig

# %% [markdown]
# ## 7.3. Train Function

# %%
def train_one_epoch(model, train_loader, score_loss_fn, status_loss_fn, optimiser, device):
    '''
    Train model for one epoch.as_integer_ratio

    Returns:
        tuple: ()
    '''

    # move model to device
    model.to(device)

    # set model to training mode
    model.train()

    # initialise metrics
    # Overall metrics
    total_samples = 0.0 # total samples for each epoch

    score_loss = 0.0 # total loss for score
    status_loss = 0.0 # total loss for status
    epoch_loss = 0.0 # total loss of score and status

    # classification metrics
    all_status_output = [] # store all status output
    all_target_status = [] # store all target status


    # loop through the training data
    for X, target_score, target_status in train_loader:
        X, target_score, target_status = X.to(device), target_score.to(device), target_status.to(device) # move data to device
        
        # zero the gradients
        optimiser.zero_grad()

        # forward pass
        score_output, status_output = model(X)

        # calculate training loss
        score_loss_training = score_loss_fn(score_output, target_score) # score loss
        status_loss_training = status_loss_fn(status_output, target_status) # status loss
        total_loss_training = score_loss_training + status_loss_training # total loss

        # backward pass
        total_loss_training.backward()
        optimiser.step()

        # metrics computation
        batch_size = X.size(0)
        score_loss += score_loss_training.item() * batch_size
        status_loss += status_loss_training.item() * batch_size
        epoch_loss += total_loss_training.item() * batch_size
        total_samples += batch_size

        # collect classification metrics
        all_status_output.append(status_output) # append status output
        all_target_status.append(target_status) # append target status
    
    # average training loss
    avg_score_loss = score_loss / total_samples
    avg_status_loss = status_loss / total_samples
    avg_training_loss = epoch_loss / total_samples

    # calculate classification metrics for status
    all_status_output = torch.cat(all_status_output, dim=0) # concatenate all status output
    all_target_status = torch.cat(all_target_status, dim=0) # concatenate all target status
    classification_metrics = compute_classification_metrics(all_status_output, all_target_status)

    # plot confusion matrix
    class_names = ['Approved', 'Rejected']
    fig = plot_confusion_matrix(all_target_status, all_status_output, class_names)

    return avg_score_loss, avg_status_loss, avg_training_loss, classification_metrics, fig


def evaluate_model(model, val_loader, score_loss_fn, status_loss_fn, device):
    '''
    Evaluate the model on the validation set

    Returns: 
        tuple: ()
    '''
    # move model to device
    model.to(device)
    
    # set model to evaluation mode
    model.eval()

    # initialise overall metrics
    total_samples = 0.0 # total samples for each epoch

    score_loss = 0.0 # total loss for score
    status_loss = 0.0 # total loss for status
    epoch_loss = 0.0 # total loss of score and status

    # classification metrics
    all_status_output = [] # store all status output
    all_target_status = [] # store all target status


    # no gradient computation
    with torch.no_grad():
        # loop through the validation data
        for X, target_score, target_status in val_loader:
            X, target_score, target_status = X.to(device), target_score.to(device), target_status.to(device)

            # forward pass
            score_output, status_output = model(X)

            # calculate score loss
            score_loss_val = score_loss_fn(score_output, target_score) # score loss
            status_loss_val = status_loss_fn(status_output, target_status) # status loss
            total_loss = score_loss_val + status_loss_val # total loss

            # metrics computation
            batch_size = X.size(0)
            total_samples += batch_size

            score_loss += score_loss_val.item() * batch_size
            status_loss += status_loss_val.item() * batch_size
            epoch_loss += total_loss.item() * batch_size

            # calculate metrics for status
            all_status_output.append(status_output) # append status output
            all_target_status.append(target_status) # append target status
    
    # average validation loss
    avg_score_loss = score_loss / total_samples
    avg_status_loss = status_loss / total_samples
    avg_val_loss = epoch_loss / total_samples

    # calculate classification metrics for status
    all_status_output = torch.cat(all_status_output, dim=0) # concatenate all status output
    all_target_status = torch.cat(all_target_status, dim=0) # concatenate all target status
    classification_metrics = compute_classification_metrics(all_status_output, all_target_status)

    # plot confusion matrix
    class_names = ['Approved', 'Rejected']
    fig = plot_confusion_matrix(all_target_status, all_status_output, class_names)

    return avg_score_loss, avg_status_loss, avg_val_loss, classification_metrics, fig

# %% [markdown]
# # 8. Early Stopping and Model Checkpoint

# %%
# === Early Stopping logic ===
class EarlyStopping:
    '''
    Early stopping to stop the training when the loss does not improve after certain epochs
        Returns: bool value for stopping_training
    '''
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_val_loss = float('inf')
        self.wait = 0
        self.stopped_train = False

    def __call__(self, val_loss):
        '''
        Return True is early stopping criteria are met'''
        if val_loss < self.best_val_loss - self.min_delta:
            self.best_val_loss = val_loss # update best validation loss
            self.wait = 0 # reset patience counter
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_train = True
        return self.stopped_train
    
# === Save the best model ===
def save_checkpoint(model, file_name):
    checkpoint_path = checkpoint_dir
    os.makedirs(checkpoint_path, exist_ok=True)
    model_save_path = f'{checkpoint_path}/{file_name}.pth'
    torch.save(model.state_dict(), model_save_path)
    print(f'Model saved to {model_save_path}')

# %% [markdown]
# # 9. Main Train Loop

# %%
# === Main Train Loop ===

early_stopping = EarlyStopping(patience=patience, min_delta=min_delta)

for epoch in range(epochs):
    # train for one epoch
    train_avg_score_loss, train_avg_status_loss, train_avg_loss, classification_metrics, train_fig = train_one_epoch(model, train_loader, score_loss_fn, status_loss_fn, optimizer, device)

    # evaluate on validation set
    val_avg_score_loss, val_status_loss, val_avg_loss, classification_metrics, val_fig = evaluate_model(model, val_loader, score_loss_fn, status_loss_fn, device)

    print(f'Epoch {epoch+1}/{epochs}, Average Train Loss: {train_avg_loss:.4f}, Average Val Loss: {val_avg_loss:.4f}')
    print(f'Classification Metrics: {classification_metrics}')

    # tensorboard logging
    writer.add_scalar('Combine Loss/train', train_avg_loss, global_step=epoch)
    writer.add_scalar('Combine Loss/val', val_avg_loss, global_step=epoch)

    writer.add_scalar('Score Loss/train', train_avg_score_loss, global_step=epoch)
    writer.add_scalar('Score Loss/val', val_avg_score_loss, global_step=epoch)

    writer.add_scalar('Status Loss/train', train_avg_status_loss, global_step=epoch)
    writer.add_scalar('Status Loss/val', val_status_loss, global_step=epoch)

    writer.add_scalar('Classification Metrics/accuracy', classification_metrics['accuracy'], global_step=epoch)
    writer.add_scalar('Classification Metrics/precision', classification_metrics['precision'], global_step=epoch)
    writer.add_scalar('Classification Metrics/recall', classification_metrics['recall'], global_step=epoch)
    writer.add_scalar('Classification Metrics/f1', classification_metrics['f1'], global_step=epoch)

    writer.add_figure('Confusion Matrix/train', train_fig, global_step=epoch)
    writer.add_figure('Confusion Matrix/val', val_fig, global_step=epoch)

    writer.flush()

    # check early stoping condition before saving the model
    if early_stopping(val_avg_loss):
        print(f'Early stopping triggered at {epoch+1} epoch')
        break
    
    # track patience
    print(f'Patience: {early_stopping.wait}/{early_stopping.patience}')
    
    # save the best model
    if early_stopping.wait == 0:
        save_checkpoint(model, file_name='loan_best_model')
# Out:
# Epoch 1/100, Average Train Loss: 0.6532, Average Val Loss: 0.4641
# Classification Metrics: {'accuracy': 0.7780907204269196, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0}
# Patience: 0/10
# Model saved to /mnt/d/torch-playground/checkpoints/2025_03_24_10_08_27/loan_best_model.pth
# /home/vietanhdong/anaconda3/envs/env-torch/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 2/100, Average Train Loss: 0.3538, Average Val Loss: 0.3010
# Classification Metrics: {'accuracy': 0.8563593240438778, 'precision': 0.7021439509954058, 'recall': 0.612558450233801, 'f1': 0.6542989653942205}
# Patience: 0/10
# Model saved to /mnt/d/torch-playground/checkpoints/2025_03_24_10_08_27/loan_best_model.pth
# ...

# %% [markdown]
# # 10. Load Model and Evaluate on Test Data

# %%
# Load the best model checkpoint
model.load_state_dict(torch.load(f'{checkpoint_dir}/loan_best_model.pth'))
model.to(device)
model.eval()

# Evaluate the model on the test dataset
test_score_loss, test_avg_status_loss, test_avg_loss, classification_metrics, test_fig = evaluate_model(
    model=model,
    val_loader=test_loader,
    score_loss_fn=score_loss_fn,
    status_loss_fn=status_loss_fn,
    device=device
)
writer.add_figure('Confusion Matrix/test', test_fig)
writer.flush()  
writer.close()

print(f'Average Score Test Loss: {test_score_loss:.4f}, Average Status Test Loss: {test_avg_status_loss:.4f}, Average Test Loss: {test_avg_loss:.4f}')
print(f'Test Classification Metrics: {classification_metrics}')
# Out:
# Average Score Test Loss: 0.0113, Average Status Test Loss: 0.2346, Average Test Loss: 0.2459
# Test Classification Metrics: {'accuracy': 0.8877853542840202, 'precision': 0.7478260869565218, 'recall': 0.7463284379172229, 'f1': 0.747076511861009}
