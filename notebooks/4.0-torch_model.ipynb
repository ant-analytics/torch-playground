# %% [markdown]
# # 1. Introduction

# %%
import os
import time
from datetime import datetime
import numpy as np
import pandas as pd

# pytorch related
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import Dataset, DataLoader

# utils libraries
from tqdm import tqdm
import yaml # for config file

# %%
# set global state
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_cpu = os.cpu_count()
print(f'This machine run on {device} with {num_cpu} cpus')

# fundtion load config
def load_config(config_path):
    with open(config_path, 'r') as file:
        config = yaml.safe_load(file)
    return config

# load config
config = load_config('/mnt/d/torch-playground/scripts/config.yaml')

# %% [markdown]
# # 2. Dataset and Dataloader

# %%
# create custom dataset class
class CustomDataset(Dataset):
    '''
    Custom dataset class for loading
    input: file path
    output: tensor
    '''
    def __init__(self, file_path, target_status, target_score):
        self.file_path = file_path
        self.target_status = target_status
        self.target_score = target_score
        self.data = pd.read_csv(file_path)

        self.X = self.data.drop([target_status, target_score], axis=1)
        self.y_status = self.data[target_status]
        self.y_score = self.data[target_score]

    def __len__(self):
        '''
        return the number of samples
        '''
        return len(self.data)
    
    def __getitem__(self, idx):
        '''
        return the sample at index idx
        if use .reshape(-1, 1) to add dimension --> every sample will be shape (1,1)
        when batched, it will be shape (batch_size, 1, 1)
        if use .unsqueeze(-1) to add dimension --> every sample will be shape (1,)
        when batched, it will be shape (batch_size, 1); use .unsqueeze(-1) recommended
        '''
        
        X = torch.tensor(self.X.iloc[idx].values, dtype=torch.float32)
        target_status = torch.tensor(self.y_status.iloc[idx], dtype=torch.float32).unsqueeze(-1) # add dimension
        target_score = torch.tensor(self.y_score.iloc[idx], dtype=torch.float32).unsqueeze(-1) # add dimension
        return X, target_score, target_status

# %% [markdown]
# # 3. Project Hyperparameters

# %%
# set hyperparameters
# data 
train_path = config['data']['train_path']
val_path = config['data']['val_path']
test_path = config['data']['test_path']
target_status = config['data']['target_status']
target_score = config['data']['target_score']
batch_size = config['training']['batch_size']

# model
input_size = config['model']['input_size']
hidden_size_1 = config['model']['hidden_size_1']
hidden_size_2 = config['model']['hidden_size_2']
hidden_size_3 = config['model']['hidden_size_3']
output_size_status = config['model']['output_size_status']
output_size_score = config['model']['output_size_score']

# training
learning_rate = config['training']['learning_rate']
epochs = config['training']['epochs']
patience = config['training']['patience']
min_delta = config['training']['min_delta']

# logging
timestamp = datetime.now().strftime('%Y_%m_%d_%H_%M_%S')

# checkpoint directory
checkpoint_dir = f"{config['logging']['checkpoint_dir']}/{timestamp}"

# tensorboard log directory
tensorboard_log_dir = f'{config['logging']['tensorboard_log_dir']}/{timestamp}'
writer = SummaryWriter(log_dir=tensorboard_log_dir) # initialise tensorboard writer

# %%
# train dataset and train loader
train_dataset = CustomDataset(file_path=train_path, target_status=target_status, target_score=target_score)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_cpu)

# validation dataset and validation loader
val_dataset = CustomDataset(file_path=val_path, target_status=target_status, target_score=target_score)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_cpu)

# test dataset and test loader
test_dataset = CustomDataset(test_path, target_status=target_status, target_score=target_score)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_cpu)

# %%
for i, (X, y_status, y_score) in enumerate(train_loader):
    print(f'this is shape of X: {X.shape}')
    print(f'this is shape of y_status: {y_status.shape}')
    print(f'this is shape of y_score: {y_score.shape}')
    break

# %% [markdown]
# # 4. Model Architecture

# %%
# model architecture
class LoanModel(nn.Module):
    '''
    Docstring for LoanModel
    '''
    def __init__(self, input_size, hidden_size_1, hidden_size_2, hidden_size_3, output_size_score, output_size_status):
        '''
        Docstring for __init__
        '''
        super().__init__() # no need to pass class and self

        # shared layers
        self.fc1 = nn.Linear(input_size, hidden_size_1)
        self.fc2 = nn.Linear(hidden_size_1, hidden_size_2)
        self.fc3 = nn.Linear(hidden_size_2, hidden_size_3)
        
        # output layer for regression
        self.regression_head = nn.Linear(hidden_size_3, output_size_score) # output size for regression

        # output layer for binary classification
        self.classification_head = nn.Linear(hidden_size_3, output_size_status) # output size for classification

    def forward(self, x):
        '''
        Docstring for forward
        '''
        # shared layers
        # relu activation function for hidden layers
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))

        # regression head
        score_output = self.regression_head(x) # no activation function for regression

        # classification head
        # sigmoid for binary classification
        status_output = torch.sigmoid(self.classification_head(x))

        return score_output, status_output

# %% [markdown]
# # 5. Loss Function

# %%
# loss for credit score
score_loss_fn = nn.MSELoss(reduction='mean')
status_loss_fn = nn.BCELoss(reduction='mean')

# %% [markdown]
# # 6. Optimiser

# %%
#  instantiate model
model = LoanModel(input_size, hidden_size_1, hidden_size_2, hidden_size_3, output_size_score, output_size_status).to(device)

# score optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # 7. Train and Evaluate Functions

# %%
def train_one_epoch(model, train_loader, score_loss_fn, status_loss_fn, optimiser, device):
    '''
    Docstring for train_one_epoch
    :type device: '''

    # move model to device
    model.to(device)

    # set model to training mode
    model.train()

    # initialise metrics
    epoch_loss = 0.0 # total loss for each epoch
    total_samples = 0.0 # total samples for each epoch

    # loop through the training data
    for X, target_score, target_status in train_loader:
        X, target_score, target_status = X.to(device), target_score.to(device), target_status.to(device) # move data to device

        # forward pass
        score_output, status_output = model(X)

        # calculate training loss for score
        score_loss_training = score_loss_fn(score_output, target_score)

        # calculate training loss for status
        status_loss_training = status_loss_fn(status_output, target_status)

        # total training loss
        total_loss_training = score_loss_training + status_loss_training

        # backward pass
        optimiser.zero_grad()
        total_loss_training.backward()
        optimiser.step()

        # metrics computation
        batch_size = X.size(0)
        epoch_loss += total_loss_training.item() * batch_size
        total_samples += batch_size
    
    # average training loss
    avg_training_loss = epoch_loss / total_samples
    print(f'Average Training Loss: {avg_training_loss:.4f}')

    return avg_training_loss

def evaluate_model(model, val_loader, score_loss_fn, status_loss_fn, device):
    '''
    Docstring for evaluate_model
    :type device: '''
    # set model to evaluation mode
    model.eval()
    epoch_loss = 0.0
    total_samples = 0.0

    # no gradient computation
    with torch.no_grad():
        # loop through the validation data
        for X, target_score, target_status in val_loader:
            X, target_score, target_status = X.to(device), target_status.to(device), target_score.to(device)

            # forward pass
            score_output, status_output = model(X)

            # calculate score loss
            score_loss_val = score_loss_fn(score_output, target_score)

            # calculate status loss
            status_loss_val = status_loss_fn(status_output, target_status)

            # total loss
            total_loss = score_loss_val + status_loss_val

            # metrics computation
            batch_size = X.size(0)
            total_samples += batch_size
            epoch_loss += total_loss.item() * batch_size
    
    # average validation loss
    avg_val_loss = epoch_loss / total_samples
    print(f'Average Validation Loss: {avg_val_loss:.4f}')

    return avg_val_loss

# %% [markdown]
# # 8. Early Stopping and Model Checkpoint

# %%
# === Early Stopping logic ===
class EarlyStoping:
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_val_loss = float('inf')
        self.wait = 0
        self.stopped_train = False

    def __call__(self, val_loss):
        if self.best_val_loss - val_loss > self.min_delta:
            self.best_val_loss = val_loss
            self.wait = 0
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.stopped_train = True
        return self.stopped_train
    
# === Save the best model ===
def save_checkpoint(model, file_name):
    checkpoint_path = checkpoint_dir
    os.makedirs(checkpoint_path, exist_ok=True)
    model_save_path = f'{checkpoint_path}/{file_name}.pth'
    torch.save(model.state_dict(), model_save_path)
    print(f'Model saved to {model_save_path}')

# %% [markdown]
# # 9. Main Train Loop

# %%
# === Main Train Loop ===

early_stoping = EarlyStoping(patience=patience, min_delta=min_delta)

for epoch in range(epochs):
    # train for one epoch
    train_loss = train_one_epoch(model, train_loader, score_loss_fn, status_loss_fn, optimizer, device)

    # evaluate on validation set
    val_loss = evaluate_model(model, val_loader, score_loss_fn, status_loss_fn, device)

    print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')

    # tensorboard logging
    writer.add_scalar('Loss/train', train_loss, global_step=epoch)
    writer.add_scalar('Loss/val', val_loss, global_step=epoch)
    writer.flush()

    # # early stoping
    # if early_stoping(val_loss):
    #     print(f'Early stopping triggered at {epoch+1} epoch')
    #     break
    # # save the best model
    # # Ensure the directory exists before saving the model
    # # os.makedirs(f'{checkpoint_dir}/{timestamp}', exist_ok=True)
    # save_checkpoint(model, file_name='loan_best_model')
# Out:
# Average Training Loss: 0.2287
# Average Validation Loss: 3.5134
# Epoch 1/100, Train Loss: 0.2287, Val Loss: 3.5134
# Average Training Loss: 0.2277
# Average Validation Loss: 3.4943
# Epoch 2/100, Train Loss: 0.2277, Val Loss: 3.4943
# Average Training Loss: 0.2271
# Average Validation Loss: 3.5910
# Epoch 3/100, Train Loss: 0.2271, Val Loss: 3.5910
# Average Training Loss: 0.2266
# Average Validation Loss: 3.6130
# Epoch 4/100, Train Loss: 0.2266, Val Loss: 3.6130
# Average Training Loss: 0.2262
# Average Validation Loss: 3.6552
# Epoch 5/100, Train Loss: 0.2262, Val Loss: 3.6552
# Average Training Loss: 0.2251
# Average Validation Loss: 3.6375
# Epoch 6/100, Train Loss: 0.2251, Val Loss: 3.6375
# Average Training Loss: 0.2247
# Average Validation Loss: 3.6884
# Epoch 7/100, Train Loss: 0.2247, Val Loss: 3.6884
# Average Training Loss: 0.2241
# Average Validation Loss: 3.6700
# Epoch 8/100, Train Loss: 0.2241, Val Loss: 3.6700
# Average Training Loss: 0.2236
# Average Validation Loss: 3.6616
# Epoch 9/100, Train Loss: 0.2236, Val Loss: 3.6616
# Average Training Loss: 0.2228
# Average Validation Loss: 3.8008
# Epoch 10/100, Train Loss: 0.2228, Val Loss: 3.8008
# Average Training Loss: 0.2225
# Average Validation Loss: 3.7039
# Epoch 11/100, Train Loss: 0.2225, Val Loss: 3.7039
# Average Training Loss: 0.2217
# Average Validation Loss: 3.7595
# Epoch 12/100, Train Loss: 0.2217, Val Loss: 3.7595
# Average Training Loss: 0.2208
# Average Validation Loss: 3.7899
# Epoch 13/100, Train Loss: 0.2208, Val Loss: 3.7899
# Average Training Loss: 0.2203
# Average Validation Loss: 3.7892
# Epoch 14/100, Train Loss: 0.2203, Val Loss: 3.7892
# Average Training Loss: 0.2195
# Average Validation Loss: 3.8186
# Epoch 15/100, Train Loss: 0.2195, Val Loss: 3.8186
# Average Training Loss: 0.2189
# Average Validation Loss: 3.8708
# Epoch 16/100, Train Loss: 0.2189, Val Loss: 3.8708
# Average Training Loss: 0.2183
# Average Validation Loss: 3.9146
# Epoch 17/100, Train Loss: 0.2183, Val Loss: 3.9146
# Average Training Loss: 0.2179
# Average Validation Loss: 3.8388
# Epoch 18/100, Train Loss: 0.2179, Val Loss: 3.8388
# Average Training Loss: 0.2172
# Average Validation Loss: 3.9097
# Epoch 19/100, Train Loss: 0.2172, Val Loss: 3.9097
# Average Training Loss: 0.2167
# Average Validation Loss: 3.8652
# Epoch 20/100, Train Loss: 0.2167, Val Loss: 3.8652
# Average Training Loss: 0.2159
# Average Validation Loss: 3.9591
# Epoch 21/100, Train Loss: 0.2159, Val Loss: 3.9591
# Average Training Loss: 0.2153
# Average Validation Loss: 3.9561
# Epoch 22/100, Train Loss: 0.2153, Val Loss: 3.9561
# Average Training Loss: 0.2149
# Average Validation Loss: 3.9102
# Epoch 23/100, Train Loss: 0.2149, Val Loss: 3.9102
# Average Training Loss: 0.2142
# Average Validation Loss: 3.9399
# Epoch 24/100, Train Loss: 0.2142, Val Loss: 3.9399
# Average Training Loss: 0.2138
# Average Validation Loss: 3.9664
# Epoch 25/100, Train Loss: 0.2138, Val Loss: 3.9664
# Average Training Loss: 0.2130
# Average Validation Loss: 3.9603
# Epoch 26/100, Train Loss: 0.2130, Val Loss: 3.9603
# Average Training Loss: 0.2128
# Average Validation Loss: 4.0282
# Epoch 27/100, Train Loss: 0.2128, Val Loss: 4.0282
# Average Training Loss: 0.2117
# Average Validation Loss: 4.0521
# Epoch 28/100, Train Loss: 0.2117, Val Loss: 4.0521
# Average Training Loss: 0.2113
# Average Validation Loss: 4.0588
# Epoch 29/100, Train Loss: 0.2113, Val Loss: 4.0588
# Average Training Loss: 0.2108
# Average Validation Loss: 4.0292
# Epoch 30/100, Train Loss: 0.2108, Val Loss: 4.0292
# Average Training Loss: 0.2102
# Average Validation Loss: 4.1174
# Epoch 31/100, Train Loss: 0.2102, Val Loss: 4.1174
# Average Training Loss: 0.2096
# Average Validation Loss: 4.1131
# Epoch 32/100, Train Loss: 0.2096, Val Loss: 4.1131
# Average Training Loss: 0.2094
# Average Validation Loss: 4.0348
# Epoch 33/100, Train Loss: 0.2094, Val Loss: 4.0348
# Average Training Loss: 0.2090
# Average Validation Loss: 4.1006
# Epoch 34/100, Train Loss: 0.2090, Val Loss: 4.1006
# Average Training Loss: 0.2083
# Average Validation Loss: 4.1576
# Epoch 35/100, Train Loss: 0.2083, Val Loss: 4.1576
# Average Training Loss: 0.2077
# Average Validation Loss: 4.1214
# Epoch 36/100, Train Loss: 0.2077, Val Loss: 4.1214
# Average Training Loss: 0.2071
# Average Validation Loss: 4.1159
# Epoch 37/100, Train Loss: 0.2071, Val Loss: 4.1159
# Average Training Loss: 0.2070
# Average Validation Loss: 4.1693
# Epoch 38/100, Train Loss: 0.2070, Val Loss: 4.1693
# Average Training Loss: 0.2066
# Average Validation Loss: 4.1584
# Epoch 39/100, Train Loss: 0.2066, Val Loss: 4.1584
# Average Training Loss: 0.2060
# Average Validation Loss: 4.1638
# Epoch 40/100, Train Loss: 0.2060, Val Loss: 4.1638
# Average Training Loss: 0.2056
# Average Validation Loss: 4.1863
# Epoch 41/100, Train Loss: 0.2056, Val Loss: 4.1863
# Average Training Loss: 0.2054
# Average Validation Loss: 4.1939
# Epoch 42/100, Train Loss: 0.2054, Val Loss: 4.1939
# Average Training Loss: 0.2052
# Average Validation Loss: 4.1883
# Epoch 43/100, Train Loss: 0.2052, Val Loss: 4.1883
# Average Training Loss: 0.2044
# Average Validation Loss: 4.1925
# Epoch 44/100, Train Loss: 0.2044, Val Loss: 4.1925
# Average Training Loss: 0.2046
# Average Validation Loss: 4.1992
# Epoch 45/100, Train Loss: 0.2046, Val Loss: 4.1992
# Average Training Loss: 0.2044
# Average Validation Loss: 4.2314
# Epoch 46/100, Train Loss: 0.2044, Val Loss: 4.2314
# Average Training Loss: 0.2032
# Average Validation Loss: 4.1722
# Epoch 47/100, Train Loss: 0.2032, Val Loss: 4.1722
# Average Training Loss: 0.2034
# Average Validation Loss: 4.2003
# Epoch 48/100, Train Loss: 0.2034, Val Loss: 4.2003
# Average Training Loss: 0.2025
# Average Validation Loss: 4.2068
# Epoch 49/100, Train Loss: 0.2025, Val Loss: 4.2068
# Average Training Loss: 0.2021
# Average Validation Loss: 4.2136
# Epoch 50/100, Train Loss: 0.2021, Val Loss: 4.2136
# Average Training Loss: 0.2020
# Average Validation Loss: 4.2927
# Epoch 51/100, Train Loss: 0.2020, Val Loss: 4.2927
# Average Training Loss: 0.2018
# Average Validation Loss: 4.2748
# Epoch 52/100, Train Loss: 0.2018, Val Loss: 4.2748
# Average Training Loss: 0.2019
# Average Validation Loss: 4.3051
# Epoch 53/100, Train Loss: 0.2019, Val Loss: 4.3051
# Average Training Loss: 0.2013
# Average Validation Loss: 4.3002
# Epoch 54/100, Train Loss: 0.2013, Val Loss: 4.3002
# Average Training Loss: 0.2009
# Average Validation Loss: 4.2275
# Epoch 55/100, Train Loss: 0.2009, Val Loss: 4.2275
# Average Training Loss: 0.2009
# Average Validation Loss: 4.2789
# Epoch 56/100, Train Loss: 0.2009, Val Loss: 4.2789
# Average Training Loss: 0.2004
# Average Validation Loss: 4.2140
# Epoch 57/100, Train Loss: 0.2004, Val Loss: 4.2140
# Average Training Loss: 0.2006
# Average Validation Loss: 4.2513
# Epoch 58/100, Train Loss: 0.2006, Val Loss: 4.2513
# Average Training Loss: 0.1996
# Average Validation Loss: 4.2711
# Epoch 59/100, Train Loss: 0.1996, Val Loss: 4.2711
# Average Training Loss: 0.1999
# Average Validation Loss: 4.2344
# Epoch 60/100, Train Loss: 0.1999, Val Loss: 4.2344
# Average Training Loss: 0.1997
# Average Validation Loss: 4.2182
# Epoch 61/100, Train Loss: 0.1997, Val Loss: 4.2182
# Average Training Loss: 0.1993
# Average Validation Loss: 4.2988
# Epoch 62/100, Train Loss: 0.1993, Val Loss: 4.2988
# Average Training Loss: 0.1989
# Average Validation Loss: 4.2703
# Epoch 63/100, Train Loss: 0.1989, Val Loss: 4.2703
# Average Training Loss: 0.1987
# Average Validation Loss: 4.2961
# Epoch 64/100, Train Loss: 0.1987, Val Loss: 4.2961
# Average Training Loss: 0.1984
# Average Validation Loss: 4.3136
# Epoch 65/100, Train Loss: 0.1984, Val Loss: 4.3136
# Average Training Loss: 0.1983
# Average Validation Loss: 4.2461
# Epoch 66/100, Train Loss: 0.1983, Val Loss: 4.2461
# Average Training Loss: 0.1980
# Average Validation Loss: 4.2847
# Epoch 67/100, Train Loss: 0.1980, Val Loss: 4.2847
# Average Training Loss: 0.1981
# Average Validation Loss: 4.2533
# Epoch 68/100, Train Loss: 0.1981, Val Loss: 4.2533
# Average Training Loss: 0.1974
# Average Validation Loss: 4.2330
# Epoch 69/100, Train Loss: 0.1974, Val Loss: 4.2330
# Average Training Loss: 0.1982
# Average Validation Loss: 4.2181
# Epoch 70/100, Train Loss: 0.1982, Val Loss: 4.2181
# Average Training Loss: 0.1973
# Average Validation Loss: 4.2650
# Epoch 71/100, Train Loss: 0.1973, Val Loss: 4.2650
# Average Training Loss: 0.1973
# Average Validation Loss: 4.2799
# Epoch 72/100, Train Loss: 0.1973, Val Loss: 4.2799
# Average Training Loss: 0.1966
# Average Validation Loss: 4.3195
# Epoch 73/100, Train Loss: 0.1966, Val Loss: 4.3195
# Average Training Loss: 0.1966
# Average Validation Loss: 4.2521
# Epoch 74/100, Train Loss: 0.1966, Val Loss: 4.2521
# Average Training Loss: 0.1963
# Average Validation Loss: 4.2803
# Epoch 75/100, Train Loss: 0.1963, Val Loss: 4.2803
# Average Training Loss: 0.1964
# Average Validation Loss: 4.2217
# Epoch 76/100, Train Loss: 0.1964, Val Loss: 4.2217
# Average Training Loss: 0.1962
# Average Validation Loss: 4.2774
# Epoch 77/100, Train Loss: 0.1962, Val Loss: 4.2774
# Average Training Loss: 0.1962
# Average Validation Loss: 4.1835
# Epoch 78/100, Train Loss: 0.1962, Val Loss: 4.1835
# Average Training Loss: 0.1958
# Average Validation Loss: 4.2074
# Epoch 79/100, Train Loss: 0.1958, Val Loss: 4.2074
# Average Training Loss: 0.1960
# Average Validation Loss: 4.2701
# Epoch 80/100, Train Loss: 0.1960, Val Loss: 4.2701
# Average Training Loss: 0.1952
# Average Validation Loss: 4.2063
# Epoch 81/100, Train Loss: 0.1952, Val Loss: 4.2063
# Average Training Loss: 0.1952
# Average Validation Loss: 4.1969
# Epoch 82/100, Train Loss: 0.1952, Val Loss: 4.1969
# Average Training Loss: 0.1955
# Average Validation Loss: 4.2104
# Epoch 83/100, Train Loss: 0.1955, Val Loss: 4.2104
# Average Training Loss: 0.1950
# Average Validation Loss: 4.2007
# Epoch 84/100, Train Loss: 0.1950, Val Loss: 4.2007
# Average Training Loss: 0.1948
# Average Validation Loss: 4.2091
# Epoch 85/100, Train Loss: 0.1948, Val Loss: 4.2091
# Average Training Loss: 0.1945
# Average Validation Loss: 4.2691
# Epoch 86/100, Train Loss: 0.1945, Val Loss: 4.2691
# Average Training Loss: 0.1945
# Average Validation Loss: 4.1614
# Epoch 87/100, Train Loss: 0.1945, Val Loss: 4.1614
# Average Training Loss: 0.1943
# Average Validation Loss: 4.2091
# Epoch 88/100, Train Loss: 0.1943, Val Loss: 4.2091
# Average Training Loss: 0.1938
# Average Validation Loss: 4.2277
# Epoch 89/100, Train Loss: 0.1938, Val Loss: 4.2277
# Average Training Loss: 0.1937
# Average Validation Loss: 4.1991
# Epoch 90/100, Train Loss: 0.1937, Val Loss: 4.1991
# Average Training Loss: 0.1940
# Average Validation Loss: 4.2657
# Epoch 91/100, Train Loss: 0.1940, Val Loss: 4.2657
# Average Training Loss: 0.1936
# Average Validation Loss: 4.2058
# Epoch 92/100, Train Loss: 0.1936, Val Loss: 4.2058
# Average Training Loss: 0.1936
# Average Validation Loss: 4.2703
# Epoch 93/100, Train Loss: 0.1936, Val Loss: 4.2703
# Average Training Loss: 0.1932
# Average Validation Loss: 4.2323
# Epoch 94/100, Train Loss: 0.1932, Val Loss: 4.2323
# Average Training Loss: 0.1933
# Average Validation Loss: 4.2111
# Epoch 95/100, Train Loss: 0.1933, Val Loss: 4.2111
# Average Training Loss: 0.1933
# Average Validation Loss: 4.2187
# Epoch 96/100, Train Loss: 0.1933, Val Loss: 4.2187
# Average Training Loss: 0.1925
# Average Validation Loss: 4.2386
# Epoch 97/100, Train Loss: 0.1925, Val Loss: 4.2386
# Average Training Loss: 0.1924
# Average Validation Loss: 4.1602
# Epoch 98/100, Train Loss: 0.1924, Val Loss: 4.1602
# Average Training Loss: 0.1931
# Average Validation Loss: 4.2031
# Epoch 99/100, Train Loss: 0.1931, Val Loss: 4.2031
# Average Training Loss: 0.1925
# Average Validation Loss: 4.1744
# Epoch 100/100, Train Loss: 0.1925, Val Loss: 4.1744

# %%
# # Load the best model checkpoint
# # Automatically find the latest checkpoint based on the timestamp in the filename
# import glob
# import os

# checkpoint_dir = config['logging']['checkpoint_dir']
# latest_checkpoint = max(glob.glob(os.path.join(checkpoint_dir, 'loan_score_best_model_*.pth')), key=os.path.getctime)

# # Load the latest model checkpoint
# model.load_state_dict(torch.load(latest_checkpoint))
# model.to(device)
# model.eval()

# # Evaluate the model on the test dataset
# test_score_loss, test_status_loss, test_avg_loss = evaluate_model(
#     model=model,
#     val_loader=test_loader,
#     score_loss_fn=score_loss_fn,
#     status_loss_fn=status_loss_fn,
#     device=device
# )

# # # log test loss
# # writer.add_scalar('score_loss/Test', test_score_loss)
# # writer.add_scalar('status_loss/Test', test_status_loss)
# # writer.add_scalar('Average_Loss/Test', test_avg_loss)
# writer.add_scalar('Average_Loss/Training', test_avg_loss, global_step=final_epoch)
# writer.add_scalar('Average_Loss/Validation', test_avg_loss, global_step=final_epoch)

# # Flush  and close the writer
writer.flush()
writer.close()
